# %% [markdown]
# # 处理数据

# %% [markdown]
# 进入代码目录：

# %%
cd ../../apps/
# Out:
# e:\kaggle\pytorch-book\apps

# %% [markdown]
# 载入模块：

# %%
from utils.loader_all import Record
from utils.torch_loader_all import Loader
from tools.split import PathSet
from tools.file import mkdir

# %% [markdown]
# ## 图片可视化

# %%
# 数据集根目录
root = r"E:\kaggle\datasets\buildings"

dataset = Record(root)

# %% [markdown]
# 获取第一张图片：

# %%
img = dataset[0]
img.size
# Out:
# (4000, 1536)

# %%
img.resize((280, 200))
# Out:
# <PIL.Image.Image image mode=RGB size=280x200 at 0x122B77871C0>

# %% [markdown]
# ## 转换为 torch 数据

# %%
mask_root = 'D:/kaggle/dataset/mask/testing_mask_dataset'  # mask 根目录
fine_size = 256  # image size
batch_size = 1   # Need to be set to 1
loader = Loader(fine_size, batch_size, mask_root, root)

# %%
trainset = loader.trainset # 训练集
maskset = loader.maskset # mask 数据集
